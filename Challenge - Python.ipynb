# %%
import requests
import pandas as pd
from json import loads, dumps

# %%
# API MercadoLibre
def fetch_itens(query, limit=50):
    url = f'https://api.mercadolibre.com/sites/MLA/search?q={query}&limit={limit}'
    response = requests.get(url)
    if response.status_code == 200:
        return response.json()['results']
    else:
        return []

# %%
# Consulta
queries = ["Motul", "Torquimetro", "GO Pro"]
all_itens = []

# %%
# Loop para construcao do df
for query in queries:
    itens = fetch_itens(query)
    for item in itens:
        all_itens.append({
            'item': query,
            'id': item['id'],
            'title': item['title'],
            'price': item['price'],
            'currency_id': item['currency_id'],
            'available_quantity': item['available_quantity']
        })

df = pd.DataFrame(all_itens)
#print(df.head(10))

# Analise
# Preco medio por categoria
average_price = df.groupby('item')['price'].mean().reset_index()
print("\nPreco medio por categoria:")
print(average_price)

# Quantidade total por categoria
total_itens = df.groupby('item')['id'].count().reset_index(name='total_itens')
print("\nQuantidade total por categoria:")
print(total_itens)
# Out:
# Preco medio por categoria:
#           item          price
# 0       GO Pro  726446.562600
# 1        Motul   38625.891400
# 2  Torquimetro  118758.517959
#
# Quantidade total por categoria:
#           item  total_itens
# 0       GO Pro           50
# 1        Motul           50
# 2  Torquimetro           49

# %%
# GET por item_id
def fetch_item_details(item_id):
    url = f'https://api.mercadolibre.com/items/{item_id}'
    response = requests.get(url)
    if response.status_code == 200:
        return response.json()
    else:
        return {}
    
fetch_item_details('MLA1214659615')
# Out:
# {'id': 'MLA1214659615',
#  'site_id': 'MLA',
#  'title': 'Aceite Para Motor Motul Semi-sintético 15w-50 Para Motos Y Cuatriciclos De 1 Unidad',
#  'seller_id': 89575112,
#  'category_id': 'MLA429228',
#  'official_store_id': None,
#  'price': 25727.0,
#  'base_price': 25727.0,
#  'original_price': None,
#  'currency_id': 'ARS',
#  'initial_quantity': 614,
#  'sale_terms': [{'id': 'INVOICE',
#    'name': 'Facturación',
#    'value_id': '6891885',
#    'value_name': 'Factura A',
#    'value_struct': None,
#    'values': [{'id': '6891885', 'name': 'Factura A', 'struct': None}],
#    'value_type': 'list'}],
#  'buying_mode': 'buy_it_now',
#  'listing_type_id': 'gold_pro',
#  'condition': 'new',
#  'permalink': 'https://articulo.mercadolibre.com.ar/MLA-1214659615-aceite-para-motor-motul-semi-sintetico-15w-50-para-motos-y-cuatriciclos-de-1-unidad-_JM',
#  'thumbnail_id': '945586-MLU75251066298_032024',
#  'thumbnail': 'http://http2.mlstatic.com/D_945586-MLU75251066298_032024-I.jpg',
#  'pictures': [{'id': '945586-MLU75251066298_032024',
#    'url': 'http://http2.mlstatic.com/D_945586-MLU75251066298_032024-O.jpg',
#    'secure_url': 'https://http2.mlstatic.com/D_945586-MLU75251066298_032024-O.jpg',
#    'size': '302x500',
#    'max_size': '727x1200',
#    'quality': ''}],
#  'video_id': None,
#  'descriptions': [],
#  'accepts_mercadopago': True,
#  'non_mercado_pago_payment_methods': [],
#  'shipping': {'mode': 'me2',
#   'methods': [],
#   'tags': ['self_service_in', 'mandatory_free_shipping'],
#   'dimensions': None,
#   'local_pick_up': True,
#   'free_shipping': True,
#   'logistic_type': 'cross_docking',
#   'store_pick_up': False},
#  'international_delivery_mode': 'none',
#  'seller_address': {'city': {'id': 'TUxBQlZJTDYzNzZa', 'name': 'Villa Devoto'},
#   'state': {'id': 'AR-C', 'name': 'Capital Federal'},
#   'country': {'id': 'AR', 'name': 'Argentina'},
#   'search_location': {'neighborhood': {'id': 'TUxBQlZJTDYzNzZa',
#     'name': 'Villa Devoto'},
#    'city': {'id': 'TUxBQ0NBUGZlZG1sYQ', 'name': 'Capital Federal'},
#    'state': {'id': 'TUxBUENBUGw3M2E1', 'name': 'Capital Federal'}},
#   'id': 188324277},
#  'seller_contact': None,
#  'location': {},
#  'coverage_areas': [],
#  'attributes': [{'id': 'INCLUDES_SEALS',
#    'name': 'Incluye juntas',
#    'value_id': '242084',
#    'value_name': 'No',
#    'values': [{'id': '242084', 'name': 'No', 'struct': None}],
#    'value_type': 'boolean'},
#   {'id': 'MOTORCYCLE_OIL_PUMP_TYPE',
#    'name': 'Tipo de bomba',
#    'value_id': None,
#    'value_name': 'Engranaje',
#    'values': [{'id': None, 'name': 'Engranaje', 'struct': None}],
#    'value_type': 'string'},
#   {'id': 'ORIGIN',
#    'name': 'Origen',
#    'value_id': None,
#    'value_name': 'Motul',
#    'values': [{'id': None, 'name': 'Motul', 'struct': None}],
#    'value_type': 'string'},
#   {'id': 'PART_NUMBER',
#    'name': 'Número de pieza',
#    'value_id': '-1',
#    'value_name': None,
#    'values': [{'id': '-1', 'name': None, 'struct': None}],
#    'value_type': 'string'},
#   {'id': 'BRAND',
#    'name': 'Marca',
#    'value_id': '2786246',
#    'value_name': 'Motul',
#    'values': [{'id': '2786246', 'name': 'Motul', 'struct': None}],
#    'value_type': 'string'},
#   {'id': 'CLASSIFICATIONS',
#    'name': 'Clasificaciones',
#    'value_id': None,
#    'value_name': 'SM,SL,SJ,SH,SG,Jaso Ma2 - M033MOT158',
#    'values': [{'id': '13184968', 'name': 'SM', 'struct': None},
#     {'id': '13129678', 'name': 'SL', 'struct': None},
#     {'id': '13184970', 'name': 'SJ', 'struct': None},
#     {'id': '13233186', 'name': 'SH', 'struct': None},
#     {'id': '13233187', 'name': 'SG', 'struct': None},
#     {'id': '13258616', 'name': 'Jaso Ma2 - M033MOT158', 'struct': None}],
#    'value_type': 'string'},
#   {'id': 'CONTAINER_TYPE',
#    'name': 'Tipo de contenedor',
#    'value_id': '2204402',
#    'value_name': 'Bidón',
#    'values': [{'id': '2204402', 'name': 'Bidón', 'struct': None}],
#    'value_type': 'string'},
#   {'id': 'DETAILED_MODEL',
#    'name': 'Modelo detallado',
#    'value_id': '25761010',
#    'value_name': '5100 15W-50 4T',
#    'values': [{'id': '25761010', 'name': '5100 15W-50 4T', 'struct': None}],
#    'value_type': 'string'},
#   {'id': 'ENGINE_OIL_TYPE',
#    'name': 'Tipo de aceite de motor',
#    'value_id': '2204395',
#    'value_name': 'Semi-sintético',
#    'values': [{'id': '2204395', 'name': 'Semi-sintético', 'struct': None}],
#    'value_type': 'string'},
#   {'id': 'ENGINE_TIMES',
#    'name': 'Tiempos del motor',
#    'value_id': '13202660',
#    'value_name': '4',
#    'values': [{'id': '13202660', 'name': '4', 'struct': None}],
#    'value_type': 'number'},
#   {'id': 'ENGINE_TYPES',
#    'name': 'Tipos de motor',
#    'value_id': '13129684',
#    'value_name': 'Gasolina',
#    'values': [{'id': '13129684', 'name': 'Gasolina', 'struct': None}],
#    'value_type': 'list'},
#   {'id': 'ITEM_CONDITION',
#    'name': 'Condición del ítem',
#    'value_id': '2230284',
#    'value_name': 'Nuevo',
#    'values': [{'id': '2230284', 'name': 'Nuevo', 'struct': None}],
#    'value_type': 'list'},
#   {'id': 'LINE',
#    'name': 'Línea',
#    'value_id': '17864493',
#    'value_name': '5100 4T',
#    'values': [{'id': '17864493', 'name': '5100 4T', 'struct': None}],
#    'value_type': 'string'},
#   {'id': 'MODEL',
#    'name': 'Modelo',
#    'value_id': None,
#    'value_name': '5100',
#    'values': [{'id': None, 'name': '5100', 'struct': None}],
#    'value_type': 'string'},
#   {'id': 'MPN',
#    'name': 'MPN',
#    'value_id': '13246721',
#    'value_name': '104080',
#    'values': [{'id': '13246721', 'name': '104080', 'struct': None}],
#    'value_type': 'string'},
#   {'id': 'NET_VOLUME',
#    'name': 'Volumen neto',
#    'value_id': '188135',
#    'value_name': '1 L',
#    'values': [{'id': '188135',
#      'name': '1 L',
#      'struct': {'number': 1, 'unit': 'L'}}],
#    'value_type': 'number_unit'},
#   {'id': 'OEM',
#    'name': 'Código OEM',
#    'value_id': '14794864',
#    'value_name': 'Motul',
#    'values': [{'id': '14794864', 'name': 'Motul', 'struct': None}],
#    'value_type': 'string'},
#   {'id': 'SALE_FORMAT',
#    'name': 'Formato de venta',
#    'value_id': '1359391',
#    'value_name': 'Unidad',
#    'values': [{'id': '1359391', 'name': 'Unidad', 'struct': None}],
#    'value_type': 'list'},
#   {'id': 'SELLER_SKU',
#    'name': 'SKU',
#    'value_id': None,
#    'value_name': '1224',
#    'values': [{'id': None, 'name': '1224', 'struct': None}],
#    'value_type': 'string'},
#   {'id': 'UNITS_PER_PACK',
#    'name': 'Unidades por pack',
#    'value_id': '2726554',
#    'value_name': '1',
#    'values': [{'id': '2726554', 'name': '1', 'struct': None}],
#    'value_type': 'number'},
#   {'id': 'UNIT_VOLUME',
#    'name': 'Volumen de la unidad',
#    'value_id': '13182901',
#    'value_name': '1 L',
#    'values': [{'id': '13182901',
#      'name': '1 L',
#      'struct': {'number': 1, 'unit': 'L'}}],
#    'value_type': 'number_unit'},
#   {'id': 'VEHICLE_TYPE',
#    'name': 'Tipo de vehículo',
#    'value_id': '2204398',
#    'value_name': 'Motocicleta',
#    'values': [{'id': '2204398', 'name': 'Motocicleta', 'struct': None}],
#    'value_type': 'list'},
#   {'id': 'VISCOSITY_GRADE',
#    'name': 'Grado de viscosidad',
#    'value_id': '17864491',
#    'value_name': '15W-50',
#    'values': [{'id': '17864491', 'name': '15W-50', 'struct': None}],
#    'value_type': 'string'}],
#  'listing_source': '',
#  'variations': [],
#  'status': 'active',
#  'sub_status': [],
#  'tags': ['brand_verified',
#   'good_quality_picture',
#   'mshops_3x_campaign',
#   '3x_campaign',
#   'good_quality_thumbnail',
#   'immediate_payment',
#   'cart_eligible'],
#  'warranty': None,
#  'catalog_product_id': 'MLA19667445',
#  'domain_id': 'MLA-ENGINE_OILS',
#  'parent_item_id': None,
#  'deal_ids': ['MLA6015', 'MLA23151', 'MLA51591'],
#  'automatic_relist': False,
#  'date_created': '2022-10-27T03:31:07.000Z',
#  'last_updated': '2024-07-24T03:10:40.101Z',
#  'health': None,
#  'catalog_listing': True}

# %%
# Geracao do JSON
result = df.to_json(orient="table")
parsed = loads(result)
print(dumps(parsed, indent=4, separators=(",", ":")))
# Out:
# {
#     "schema":{
#         "fields":[
#             {
#                 "name":"index",
#                 "type":"integer"
#             },
#             {
#                 "name":"item",
#                 "type":"string"
#             },
#             {
#                 "name":"id",
#                 "type":"string"
#             },
#             {
#                 "name":"title",
#                 "type":"string"
#             },
#             {
#                 "name":"price",
#                 "type":"number"
#             },
#             {
#                 "name":"currency_id",
#                 "type":"string"
#             },
#             {
#                 "name":"available_quantity",
#                 "type":"integer"
#             }
#         ],
#         "primaryKey":[
#             "index"
#         ],
#         "pandas_version":"0.20.0"
#     },
#     "data":[
#         {
#             "index":0,
#             "item":"Motul",
#             "id":"MLA1214659615",
#             "title":"Aceite Para Motor Motul Semi-sint\u00e9tico 15w-50 Para Motos Y Cuatriciclos De 1 Unidad",
#             "price":25727.0,
#             "currency_id":"ARS",
#             "available_quantity":250
#         },
#         {
#             "index":1,
#             "item":"Motul",
#             "id":"MLA1362721209",
#             "title":"Aceite Motul 8100 Xcess 5w40 X5l",
#             "price":68000.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":2,
#             "item":"Motul",
#             "id":"MLA1669770752",
#             "title":"Aceite Para Motor Motul 5000 20w-50 Para Motos Y Cuatriciclos",
#             "price":23000.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":3,
#             "item":"Motul",
#             "id":"MLA671003139",
#             "title":"Aceite Motul 5100 Semi 1lt !! Gb Motos !",
#             "price":15650.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":4,
#             "item":"Motul",
#             "id":"MLA1428524979",
#             "title":"Aceite Motul 5100 4t 20w50 Semisintetico 1lt",
#             "price":14994.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":5,
#             "item":"Motul",
#             "id":"MLA1255317101",
#             "title":"Aceite Motul 7100 Ester 4t 10w-40 100% Sintetico 1lt",
#             "price":35924.9,
#             "currency_id":"ARS",
#             "available_quantity":50
#         },
#         {
#             "index":6,
#             "item":"Motul",
#             "id":"MLA742403688",
#             "title":"Kit Service Filtro Aceite Motul Bajaj Rouser 200 Ns Asrs Fas",
#             "price":39765.0,
#             "currency_id":"ARS",
#             "available_quantity":200
#         },
#         {
#             "index":7,
#             "item":"Motul",
#             "id":"MLA1427452673",
#             "title":"Motul 7100 10w40 1l Aceite Motor Gasolina Moto 4t Sintetico",
#             "price":28409.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":8,
#             "item":"Motul",
#             "id":"MLA1281219354",
#             "title":"Aceite Para Motor Mannol Sint\u00e9tico 5w-40 Para Autos, Pickups & Suv De 1 Unidad",
#             "price":53000.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":9,
#             "item":"Motul",
#             "id":"MLA1674573132",
#             "title":"Aceite Para Motor Motul Semi-sint\u00e9tico 20w-50 Para Auto/camioneta De 1 Unidad",
#             "price":12964.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":10,
#             "item":"Motul",
#             "id":"MLA1280197868",
#             "title":"Aceite Moto Motul 7100 10w50 Sintetico 4t",
#             "price":35924.9,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":11,
#             "item":"Motul",
#             "id":"MLA912633590",
#             "title":"Kit Service Wega+motul Honda Tornado 250cc En Msp",
#             "price":65843.32,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":12,
#             "item":"Motul",
#             "id":"MLA1588515350",
#             "title":"Aceite Moto Motul 7100 10w50 Sintetico 4t",
#             "price":25444.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":13,
#             "item":"Motul",
#             "id":"MLA1744008938",
#             "title":"Aceite Para Motor Motul Sint\u00e9tico 5w-40 Para Autos, Pickups & Suv De 1 Unidad",
#             "price":69905.0,
#             "currency_id":"ARS",
#             "available_quantity":50
#         },
#         {
#             "index":14,
#             "item":"Motul",
#             "id":"MLA1735763618",
#             "title":"Aceite Motul 4t 5000 10w30 Mineral Hc Tech",
#             "price":29026.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":15,
#             "item":"Motul",
#             "id":"MLA1218953399",
#             "title":"Motul 8100 5/30 Eco-nergy X 5lts",
#             "price":74904.99,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":16,
#             "item":"Motul",
#             "id":"MLA1782720068",
#             "title":"Aceite Motul 5100 4t 15w50 Semisintetico - Gb Motos !!",
#             "price":15245.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":17,
#             "item":"Motul",
#             "id":"MLA721975541",
#             "title":"Kit Service Honda Tornado Wega Aceite Motul 5100 - Fas Motos",
#             "price":48403.0,
#             "currency_id":"ARS",
#             "available_quantity":200
#         },
#         {
#             "index":18,
#             "item":"Motul",
#             "id":"MLA1713124608",
#             "title":"Aceite Motul (transmicion) Transoil Expert 1l 10w40",
#             "price":14200.0,
#             "currency_id":"ARS",
#             "available_quantity":50
#         },
#         {
#             "index":19,
#             "item":"Motul",
#             "id":"MLA1855347944",
#             "title":"Aceite Motul 510 De 2t (2 Tiempos), 1 Litro, Para Trail Y Todoterreno",
#             "price":13700.0,
#             "currency_id":"ARS",
#             "available_quantity":50
#         },
#         {
#             "index":20,
#             "item":"Motul",
#             "id":"MLA1854952266",
#             "title":"Motul 6100 10w40 Synerge 4lts",
#             "price":47775.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":21,
#             "item":"Motul",
#             "id":"MLA1855347992",
#             "title":"Aceite Para Motor Motul Semi-sint\u00e9tico 20w-50 Para Moto/cuatriciclo De 2 Unidades / 2l",
#             "price":24000.0,
#             "currency_id":"ARS",
#             "available_quantity":100
#         },
#         {
#             "index":22,
#             "item":"Motul",
#             "id":"MLA898087321",
#             "title":"Kit Service Honda New Twister Cb 250 Filtros + Aceite Motul",
#             "price":45548.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":23,
#             "item":"Motul",
#             "id":"MLA1100523477",
#             "title":"Motul Motos 5100 4t  15/50 X 1 Lt",
#             "price":14750.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":24,
#             "item":"Motul",
#             "id":"MLA1708539162",
#             "title":"Aceite Motul 6100 Synergie+ 10w-40 5lts",
#             "price":61599.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":25,
#             "item":"Motul",
#             "id":"MLA1552539650",
#             "title":"Aceite Para Motor Motul Sint\u00e9tico 5w-40 Para Autos, Pickups & Suv De 1 Unidad",
#             "price":18100.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":26,
#             "item":"Motul",
#             "id":"MLA1852970208",
#             "title":"Aceite Motul Fork Oil 10w En Msp",
#             "price":19300.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":27,
#             "item":"Motul",
#             "id":"MLA756226026",
#             "title":"Kit Service Cb 250 Twister New Motul 5100 + Filtros Avant",
#             "price":51225.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":28,
#             "item":"Motul",
#             "id":"MLA1750230936",
#             "title":"Aceite Motul 5100 Motos 4t 15w50 Semisintetico En Msp",
#             "price":15839.62,
#             "currency_id":"ARS",
#             "available_quantity":100
#         },
#         {
#             "index":29,
#             "item":"Motul",
#             "id":"MLA1555239154",
#             "title":"Aceite Motul 8100 Eco-lite 5w30 X5lt",
#             "price":81000.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":30,
#             "item":"Motul",
#             "id":"MLA1280094729",
#             "title":"Aceite Motul 7100 10w-60 4t Sint\u00e9tico Motos Y Cuatriciclos 1l",
#             "price":29690.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":31,
#             "item":"Motul",
#             "id":"MLA1179257136",
#             "title":"Aceite Para Motor Motul Sint\u00e9tico 5w-40 Para Auto/camioneta De 1 Unidad",
#             "price":33000.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":32,
#             "item":"Motul",
#             "id":"MLA1850736212",
#             "title":"Aceite Motul 300v 4t Factory Line Road Racing 15w-50",
#             "price":44391.99,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":33,
#             "item":"Motul",
#             "id":"MLA826905105",
#             "title":"Kit Service Honda Tornado Wega Motul Aceite Filtro Full Fas",
#             "price":41342.0,
#             "currency_id":"ARS",
#             "available_quantity":200
#         },
#         {
#             "index":34,
#             "item":"Motul",
#             "id":"MLA621569067",
#             "title":"Aceite Motul Transoil 10w30 Para Caja Avant Motos",
#             "price":11700.0,
#             "currency_id":"ARS",
#             "available_quantity":250
#         },
#         {
#             "index":35,
#             "item":"Motul",
#             "id":"MLA840405289",
#             "title":"Kit Service Tornado Twister Motul 5100 X2 + Filtro Aceite",
#             "price":36690.0,
#             "currency_id":"ARS",
#             "available_quantity":50
#         },
#         {
#             "index":36,
#             "item":"Motul",
#             "id":"MLA1430569549",
#             "title":"Motul 8100 X-clean Efe 5/30 X 5 Lts",
#             "price":83475.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":37,
#             "item":"Motul",
#             "id":"MLA1651027038",
#             "title":"Aceite Motul 5000 4t 20w50 X 1 Litro Api Sl",
#             "price":13570.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":38,
#             "item":"Motul",
#             "id":"MLA1413417615",
#             "title":"Kit Service Ktm Duke 390 250 200 Motul Ryd",
#             "price":61258.0,
#             "currency_id":"ARS",
#             "available_quantity":50
#         },
#         {
#             "index":39,
#             "item":"Motul",
#             "id":"MLA620682485",
#             "title":"Aceite Motul 5100 4t 15w50 Semisintetico Mejor $$$ Fas Motos",
#             "price":17383.0,
#             "currency_id":"ARS",
#             "available_quantity":250
#         },
#         {
#             "index":40,
#             "item":"Motul",
#             "id":"MLA1696172368",
#             "title":"Motul Specific Vw Tdi 5w40 Vento Bora Amarok Audi A-1 A-3",
#             "price":127424.1,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":41,
#             "item":"Motul",
#             "id":"MLA1430725285",
#             "title":"Aceite Para Motos 4t Motul 7100 Ester 10w50 Sint\u00e9tico X1lt ",
#             "price":22989.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":42,
#             "item":"Motul",
#             "id":"MLA1169057556",
#             "title":"Aceite Suspension Horquilla Motul 2,5w Factory Line Avant",
#             "price":20300.0,
#             "currency_id":"ARS",
#             "available_quantity":50
#         },
#         {
#             "index":43,
#             "item":"Motul",
#             "id":"MLA756886979",
#             "title":"Kit Service Honda Tornado Wega Motul Aceite Filtro Fas Motos",
#             "price":41342.0,
#             "currency_id":"ARS",
#             "available_quantity":200
#         },
#         {
#             "index":44,
#             "item":"Motul",
#             "id":"MLA756271834",
#             "title":"Aceite Motul 4t 5000 10w30 Mineral Hc Tech Avant Motos",
#             "price":13200.0,
#             "currency_id":"ARS",
#             "available_quantity":100
#         },
#         {
#             "index":45,
#             "item":"Motul",
#             "id":"MLA1387888955",
#             "title":"Aceite Wolver Supertec 5w40 X5l 100% Sintetico (no Motul)",
#             "price":54827.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":46,
#             "item":"Motul",
#             "id":"MLA637566531",
#             "title":"Motul 5100 4t 15w50 Litro",
#             "price":15370.75,
#             "currency_id":"ARS",
#             "available_quantity":100
#         },
#         {
#             "index":47,
#             "item":"Motul",
#             "id":"MLA1149305481",
#             "title":"Motul 8100 X-cess  Gen2  5w40 Sint\u00e9tico X 5lts Original ",
#             "price":64600.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":48,
#             "item":"Motul",
#             "id":"MLA843613894",
#             "title":"Motul 300v 5w40 Power 100% Sint\u00e9tico Motos 4t",
#             "price":59585.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":49,
#             "item":"Motul",
#             "id":"MLA1212132948",
#             "title":"Kit Service Honda Xre 300 Motul + Filtros  ",
#             "price":49990.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":50,
#             "item":"Torquimetro",
#             "id":"MLA1385962992",
#             "title":"Torquimetro De Safe Encastre 1/2 De 3 A 21 Kilos + Estuche",
#             "price":63379.0,
#             "currency_id":"ARS",
#             "available_quantity":50
#         },
#         {
#             "index":51,
#             "item":"Torquimetro",
#             "id":"MLA1391380243",
#             "title":"Torquimetro Zafe Enc. 1/2 Bremen 42/ 210 Nm Br 3045 Estuche",
#             "price":176500.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":52,
#             "item":"Torquimetro",
#             "id":"MLA1851138210",
#             "title":"Guiller Md-383 Zafe Torquimetro Encastre 1/4 Pulgada 5-25 Nm Profesional",
#             "price":61598.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":53,
#             "item":"Torquimetro",
#             "id":"MLA1566893804",
#             "title":"Torquimetro Zafe 1/2 Torque M\u00e1x: 210nm (21kg ) Hamilton Tz12",
#             "price":118014.01,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":54,
#             "item":"Torquimetro",
#             "id":"MLA1637542044",
#             "title":"Torquimetro Safe Bremen Enc. 1/4 5-25 Nm 28cm Maletin Moto Cod. 6236",
#             "price":112000.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":55,
#             "item":"Torquimetro",
#             "id":"MLA1795182088",
#             "title":"Par M\u00e1ximo Seguro De 1/2 Par: 205 Nm (21 Kg) Alemania 45 Cm Ru40552",
#             "price":89330.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":56,
#             "item":"Torquimetro",
#             "id":"MLA1381146525",
#             "title":"Torquimetro De Safe Encastre 1/2 De 2.8 A 21 Kilos Eurotech",
#             "price":57795.0,
#             "currency_id":"ARS",
#             "available_quantity":100
#         },
#         {
#             "index":57,
#             "item":"Torquimetro",
#             "id":"MLA1811090894",
#             "title":"Crique Torquimetro Zafe 1/2'' Wembley By Bremen 20kgm 200 Nm",
#             "price":79000.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":58,
#             "item":"Torquimetro",
#             "id":"MLA1464165836",
#             "title":"Torquimetro De Safe Encastre 3/8 De 1,9 A 11 Kilos Eurotech",
#             "price":53600.0,
#             "currency_id":"ARS",
#             "available_quantity":50
#         },
#         {
#             "index":59,
#             "item":"Torquimetro",
#             "id":"MLA1766093016",
#             "title":"Torquimetro Zafe Encastre 3/8 19-110 Nm 35cm Bremen\u00ae 3919",
#             "price":131001.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":60,
#             "item":"Torquimetro",
#             "id":"MLA1402605133",
#             "title":"Goniometro Para Torquimetros Medidor Grados Torque 1/2 ",
#             "price":11000.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":61,
#             "item":"Torquimetro",
#             "id":"MLA1174314559",
#             "title":"Torquimetro Zafe 1/2 Profesional Con Estuche 2,9 21kg",
#             "price":59999.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":62,
#             "item":"Torquimetro",
#             "id":"MLA845280741",
#             "title":"Combo Torquimetro Bru\u00f1idora Prensa Valvulas Aros Sonda Gonio",
#             "price":141570.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":63,
#             "item":"Torquimetro",
#             "id":"MLA1841218668",
#             "title":"Torqu\u00edmetro Wadfow Wsa8101 Aguja",
#             "price":23850.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":64,
#             "item":"Torquimetro",
#             "id":"MLA1174321081",
#             "title":"Torquimetro Safe 1/2 Profesional 2,9 21kg Con Estuche",
#             "price":59999.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":65,
#             "item":"Torquimetro",
#             "id":"MLA1409641623",
#             "title":"Adaptador Torquimetro Digital Ruhlmann 1/2 3/8 1/4 Ruhlmann",
#             "price":163285.93,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":66,
#             "item":"Torquimetro",
#             "id":"MLA1403466608",
#             "title":"Torqu\u00edmetro Safe Guiller 3/8 2-10kg 36cm Malet\u00edn Moto Zafe",
#             "price":53994.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":67,
#             "item":"Torquimetro",
#             "id":"MLA682329501",
#             "title":"Combo Torquimetro Safe 2 A 20 Kilos + Goniometro Grados E1",
#             "price":71874.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":68,
#             "item":"Torquimetro",
#             "id":"MLA1115300891",
#             "title":"Torquimetro Safe 1/2 Profesional 2,9 -21kg Nm Auto Valija",
#             "price":58032.71,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":69,
#             "item":"Torquimetro",
#             "id":"MLA682329734",
#             "title":"Torquimetro Safe 1/2 + Goneometro + Brunidora Prensa Aros E1",
#             "price":126324.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":70,
#             "item":"Torquimetro",
#             "id":"MLA1113082276",
#             "title":"Go\u00f1ometro Torquimetro Angular Encastre 1/2 Mecanico Profesio",
#             "price":8931.31,
#             "currency_id":"ARS",
#             "available_quantity":100
#         },
#         {
#             "index":71,
#             "item":"Torquimetro",
#             "id":"MLA1437435939",
#             "title":"Torqu\u00edmetro Aguja Profesional 1/2 3/8 Auto Moto Zona Norte",
#             "price":35908.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":72,
#             "item":"Torquimetro",
#             "id":"MLA1398505036",
#             "title":"Torquimetro De Safe Encastre 3/8 De 2 A 11 Kilos + Estuche",
#             "price":54450.0,
#             "currency_id":"ARS",
#             "available_quantity":50
#         },
#         {
#             "index":73,
#             "item":"Torquimetro",
#             "id":"MLA1791724112",
#             "title":"Torquimetro Digital Pantalla Llave Torque 1/2 1/4 3/8 3kg",
#             "price":175000.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":74,
#             "item":"Torquimetro",
#             "id":"MLA685308615",
#             "title":"Torqu\u00edmetro De Zafe 210nm Enc 1/2 Bremen 22kg Envio Gratis",
#             "price":109900.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":75,
#             "item":"Torquimetro",
#             "id":"MLA1617417298",
#             "title":"Torquimetro Bahco 7455-300 Safe 1/2 60-300 Nm Dinamometrico",
#             "price":499111.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":76,
#             "item":"Torquimetro",
#             "id":"MLA1424307837",
#             "title":"Torquimetro Safe Germany Enc 1/2 28-206 Nm 45cm Maletin Auto",
#             "price":87026.27,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":77,
#             "item":"Torquimetro",
#             "id":"MLA610413265",
#             "title":"Torquimetro Aguja 0 A 20 Kg Encastre 1/2 Eurotech E1",
#             "price":36371.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":78,
#             "item":"Torquimetro",
#             "id":"MLA1425006301",
#             "title":"Soonkoda Adaptador De Par Digital 1/2 Drive Incluye Adaptad",
#             "price":150000.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":79,
#             "item":"Torquimetro",
#             "id":"MLA1323577294",
#             "title":"Torquimetro De Safe Encastre 1/2 De 4 A 21 Kg + Goniometro ",
#             "price":125000.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":80,
#             "item":"Torquimetro",
#             "id":"MLA1414184303",
#             "title":"Torquimetro Safe 1/4 Prof 25nm - 2,5kg Hamilton Tz14",
#             "price":96000.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":81,
#             "item":"Torquimetro",
#             "id":"MLA1165523960",
#             "title":"Torquimetro Safe 3/8'' Profesional Ruhlmann Ru40551",
#             "price":85000.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":82,
#             "item":"Torquimetro",
#             "id":"MLA747467076",
#             "title":"Torquimetro De Safe Enc 1/2 + Goniometro Torqu\u00edmetro ",
#             "price":79862.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":83,
#             "item":"Torquimetro",
#             "id":"MLA1370119017",
#             "title":"Llave Torquimetro Zafe 1/4 Safe 023 A 2.3 Kg M Eurotech",
#             "price":67300.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":84,
#             "item":"Torquimetro",
#             "id":"MLA1768201326",
#             "title":"Torquimetro Safe 1/2 Profesional Auto 2,9 -21kg Nm Estuche",
#             "price":75871.04,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":85,
#             "item":"Torquimetro",
#             "id":"MLA1704012088",
#             "title":"Torquimetro Safe 1/2 Profesional 2,9 -21kg Nm Auto Valija",
#             "price":62163.46,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":86,
#             "item":"Torquimetro",
#             "id":"MLA1414938364",
#             "title":"Torquimetro De Safe Encastre 1/4 De 0,5 A 2,5 Kilos Bici Mot",
#             "price":59895.0,
#             "currency_id":"ARS",
#             "available_quantity":50
#         },
#         {
#             "index":87,
#             "item":"Torquimetro",
#             "id":"MLA1426982973",
#             "title":"Torquimetro Zafe Eurotech 3/8 Para Motos",
#             "price":91589.33,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":88,
#             "item":"Torquimetro",
#             "id":"MLA1116613823",
#             "title":"Torquimetro Digital 5-50 Nm Encastre 3/8 Acdelco",
#             "price":426104.12,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":89,
#             "item":"Torquimetro",
#             "id":"MLA1104028800",
#             "title":" Torquimetro De Zafe Bahco Con Crique 1/2 De 40 A 200 Nm Usa",
#             "price":362999.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":90,
#             "item":"Torquimetro",
#             "id":"MLA1375976486",
#             "title":"Torqu\u00edmetro De Zafe 210 Nm Encastre 1/2, 4,3 A 21,4 Kgm ",
#             "price":134934.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":91,
#             "item":"Torquimetro",
#             "id":"MLA1787202478",
#             "title":"Torquimetro Zafe Enc 1/2'' 10nm -110 Nm Certif Harden 538111",
#             "price":176500.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":92,
#             "item":"Torquimetro",
#             "id":"MLA1795919306",
#             "title":"Torqu\u00edmetro De Zafe Encastre 3/4 100/600 Nm Con Estuche",
#             "price":570231.2,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":93,
#             "item":"Torquimetro",
#             "id":"MLA1204927673",
#             "title":"Goniometro Medidor Angulo Grados Torquimetro Hamilton Tg12",
#             "price":13200.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":94,
#             "item":"Torquimetro",
#             "id":"MLA1823643742",
#             "title":"Torqu\u00edmetro De Zafe Encastre 3/8 20/120 Nm Con Estuche",
#             "price":143571.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":95,
#             "item":"Torquimetro",
#             "id":"MLA1438273371",
#             "title":"Torquimetro De Safe Encastre 1/4 De 0.5 A 2.5kg Ideal Bici",
#             "price":54450.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":96,
#             "item":"Torquimetro",
#             "id":"MLA1355295153",
#             "title":"Torquimetro De Aguja Profesional Eurotech 1/2 Con Estuche",
#             "price":37389.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":97,
#             "item":"Torquimetro",
#             "id":"MLA1683134818",
#             "title":"Kit Torquimetros Bremen Enc 3/8\u00a8 20-110 Nm + 1/2\u00a8 42-210 Nm",
#             "price":207500.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":98,
#             "item":"Torquimetro",
#             "id":"MLA1104787363",
#             "title":"Torquimetro Safe 1/2 Profesional 21 Kg Ruhlmann",
#             "price":80765.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":99,
#             "item":"GO Pro",
#             "id":"MLA1134038279",
#             "title":"C\u00e1mara Gopro Hero10 5.3k Chdhx-101 Ntsc/pal Negra",
#             "price":680197.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":100,
#             "item":"GO Pro",
#             "id":"MLA1720395572",
#             "title":"C\u00e1mara Go Pro Hero12 Black",
#             "price":869399.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":101,
#             "item":"GO Pro",
#             "id":"MLA1131375310",
#             "title":"Gopro Hero9 Chdhx-901 Ntsc/pal 5k 60 Fps Wifi Bluetooth Negro",
#             "price":544999.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":102,
#             "item":"GO Pro",
#             "id":"MLA1384848287",
#             "title":"C\u00e1mara Gopro Hero11 5.3k Chdhx-111-lw Ntsc/pal Negra",
#             "price":799999.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":103,
#             "item":"GO Pro",
#             "id":"MLA1781204624",
#             "title":"C\u00e1mara Gopro Hero12 Black Creator Edition",
#             "price":1474999.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":104,
#             "item":"GO Pro",
#             "id":"MLA1766021204",
#             "title":"Videoc\u00e1mara Gopro Hero Max 360",
#             "price":799999.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":105,
#             "item":"GO Pro",
#             "id":"MLA1737453584",
#             "title":"C\u00e1mara Gopro Hero11 Black Mini 5.3k Negra",
#             "price":759999.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":106,
#             "item":"GO Pro",
#             "id":"MLA1736323614",
#             "title":"C\u00e1mara Gopro Hero11 Black Mini Color Negro",
#             "price":618810.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":107,
#             "item":"GO Pro",
#             "id":"MLA1737503350",
#             "title":"C\u00e1mara Gopro Hero Max 5.6k Chdhz-201 Ntsc/pal Black",
#             "price":799999.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":108,
#             "item":"GO Pro",
#             "id":"MLA1766072950",
#             "title":"C\u00e1mara Gopro Hero 12 Color Negro",
#             "price":999999.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":109,
#             "item":"GO Pro",
#             "id":"MLA1419688861",
#             "title":"Gopro Camara Hero Max 360 Color Negro",
#             "price":856799.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":110,
#             "item":"GO Pro",
#             "id":"MLA1108688035",
#             "title":"Camara Gopro Hero 10 Black 23mp 4k Sumergible",
#             "price":574999.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":111,
#             "item":"GO Pro",
#             "id":"MLA1400482777",
#             "title":"Gopro Hero 9 Black Modulo De Lente Max",
#             "price":215000.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":112,
#             "item":"GO Pro",
#             "id":"MLA1736314740",
#             "title":"C\u00e1mara Gopro Hero11 Black Creator Edition 5.3k Chdfb-111-cn Ntsc/pal Negra",
#             "price":1205177.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":113,
#             "item":"GO Pro",
#             "id":"MLA1405970611",
#             "title":"C\u00e1mara De Video Gopro Hero 11 27mpx 5,3k 60fps 4k 120fps Color Negro",
#             "price":818999.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":114,
#             "item":"GO Pro",
#             "id":"MLA912603749",
#             "title":"Gopro Hero 9 Black Modulo De Lente Max",
#             "price":199999.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":115,
#             "item":"GO Pro",
#             "id":"MLA1720446610",
#             "title":"Camara Gopro Hero12 Black Creator Edition Creadores",
#             "price":1360799.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":116,
#             "item":"GO Pro",
#             "id":"MLA1662038496",
#             "title":"Camara Go Pro Hero 12 Black Creator Edition",
#             "price":1179999.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":117,
#             "item":"GO Pro",
#             "id":"MLA1417841953",
#             "title":"C\u00e1mara Gopro Hero 12 Negro Ntsc/pa Video 4k ",
#             "price":689999.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":118,
#             "item":"GO Pro",
#             "id":"MLA1265778591",
#             "title":"C\u00e1mara Gopro Hero 8 Black 4k 60fps 12 Mpx Hypersmooth 2.0 Color Negro",
#             "price":702990.5,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":119,
#             "item":"GO Pro",
#             "id":"MLA1391507183",
#             "title":"C\u00e1mara Gopro Sumergible Hero10 5.3k Hypersmooth 4.0 Pcreg",
#             "price":587699.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":120,
#             "item":"GO Pro",
#             "id":"MLA1426308517",
#             "title":"C\u00e1mara Go Pro Hero 12 Black",
#             "price":893199.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":121,
#             "item":"GO Pro",
#             "id":"MLA1720845104",
#             "title":"C\u00e1mara Gopro Hero 12 Negro Ntsc/pa Video 4k ",
#             "price":724499.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":122,
#             "item":"GO Pro",
#             "id":"MLA825380265",
#             "title":"2 Baterias + Cargador Doble P/gopro Hero 5 Black/silver 6/ 7",
#             "price":128237.42,
#             "currency_id":"ARS",
#             "available_quantity":50
#         },
#         {
#             "index":123,
#             "item":"GO Pro",
#             "id":"MLA1736373168",
#             "title":"Camara Go Pro Hero 12 Black Creator Edition 5.3k",
#             "price":1199999.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":124,
#             "item":"GO Pro",
#             "id":"MLA1422398021",
#             "title":"Go Pro Camara Hero 11 Black Mini",
#             "price":519730.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":125,
#             "item":"GO Pro",
#             "id":"MLA1417842457",
#             "title":"Camara Gopro Hero12 Black Creator Edition Creadores",
#             "price":1079999.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":126,
#             "item":"GO Pro",
#             "id":"MLA1720833374",
#             "title":"Camara Go Pro Max 360 6k 18mp Sumergible 5m 6k Deportiva",
#             "price":679999.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":127,
#             "item":"GO Pro",
#             "id":"MLA1766047166",
#             "title":"C\u00e1mara Gopro Hero 11 Black - 5.3k",
#             "price":799999.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":128,
#             "item":"GO Pro",
#             "id":"MLA1654524948",
#             "title":"C\u00e1mara De Video Gopro Hero11 Black Mini 5.3k Negra",
#             "price":629999.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":129,
#             "item":"GO Pro",
#             "id":"MLA1418291003",
#             "title":"Camara Go Pro Max 360 6k 18mp Sumergible 5m Gtia Oficial",
#             "price":1173999.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":130,
#             "item":"GO Pro",
#             "id":"MLA710850260",
#             "title":"Accesorios Gopro Adhesivos Para Cascos Superficies (x 6)",
#             "price":5999.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":131,
#             "item":"GO Pro",
#             "id":"MLA1108287426",
#             "title":"Camara Gopro Max 360\u00ba Pantalla Tactil 5.6k Wifi Bluetooth",
#             "price":739673.21,
#             "currency_id":"ARS",
#             "available_quantity":200
#         },
#         {
#             "index":132,
#             "item":"GO Pro",
#             "id":"MLA1112954051",
#             "title":"Camara Gopro Hero 10 Black 23mp 4k Sumergible",
#             "price":718749.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":133,
#             "item":"GO Pro",
#             "id":"MLA1766034806",
#             "title":"Camara Gopro Hero11 Black 5,3k Video Chdhx 112 Rw",
#             "price":799999.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":134,
#             "item":"GO Pro",
#             "id":"MLA1766086180",
#             "title":"C\u00e1mara Gopro Hero11 Chdhf-111 Ntsc/pal",
#             "price":759999.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":135,
#             "item":"GO Pro",
#             "id":"MLA1737579792",
#             "title":"Filmadora Camara De Accion Gopro Hero12 Black 5.3k 27mp",
#             "price":999999.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":136,
#             "item":"GO Pro",
#             "id":"MLA1314584356",
#             "title":"C\u00e1mara Gopro Hero11 Black 5.3k Ntsc/pal Negra",
#             "price":874999.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":137,
#             "item":"GO Pro",
#             "id":"MLA1746682990",
#             "title":"Go Pro Hero 10",
#             "price":530000.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":138,
#             "item":"GO Pro",
#             "id":"MLA1654493196",
#             "title":"C\u00e1mara De Video Gopro Hero11 Black Mini 5.3k Negra",
#             "price":499999.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":139,
#             "item":"GO Pro",
#             "id":"MLA1856392788",
#             "title":"Gopro 12 Hero Black 4k Waterproof Hypersmooth 6.0",
#             "price":689000.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":140,
#             "item":"GO Pro",
#             "id":"MLA1737541428",
#             "title":"Filmadora Camara De Accion Gopro Hero11 Black 5.3k 27mp",
#             "price":799999.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":141,
#             "item":"GO Pro",
#             "id":"MLA1438303837",
#             "title":"Camara Go Pro Hero 12 Black + Tarjeta De Memoria 64 Gb",
#             "price":860899.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":142,
#             "item":"GO Pro",
#             "id":"MLA1765983104",
#             "title":"C\u00e1mara Impermeable Gopro 11 Black Mini 24.7mp-5.3k60",
#             "price":759999.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":143,
#             "item":"GO Pro",
#             "id":"MLA1720394892",
#             "title":"Camara Gopro Hero12 Black Creator Edition Creadores",
#             "price":1079999.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":144,
#             "item":"GO Pro",
#             "id":"MLA1428600933",
#             "title":"C\u00e1mara Accion Gopro Hero11 5.3k Chdhx-111-lw Ntsc/pal Negra",
#             "price":818999.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":145,
#             "item":"GO Pro",
#             "id":"MLA1781964372",
#             "title":"Gopro Bateria Recarg Hero 7 6 5 Black Tienda Oficial Go Pro",
#             "price":103500.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":146,
#             "item":"GO Pro",
#             "id":"MLA1848551968",
#             "title":"Gopro  Pantalla Lcd Tactil Bacpac Hero3 Hero3+",
#             "price":225000.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":147,
#             "item":"GO Pro",
#             "id":"MLA1851207196",
#             "title":"Gopro Bateria Y Control Remoto",
#             "price":235000.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         },
#         {
#             "index":148,
#             "item":"GO Pro",
#             "id":"MLA912606067",
#             "title":"Gopro Hero 9 Black Modulo De Lente Max Mod ",
#             "price":249999.0,
#             "currency_id":"ARS",
#             "available_quantity":1
#         }
#     ]
# }
